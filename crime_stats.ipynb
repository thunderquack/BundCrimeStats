# %%
from pathlib import Path

import pandas as pd

# %%
DATA_DIR = Path("src")

SOURCE_FILES = {
    2022: DATA_DIR / "bund-2022.xlsx",
    2023: DATA_DIR / "bund-2023.xlsx",
    2024: DATA_DIR / "bund-2024.xlsx",
}

SHEETS = {
    "by_article": "csv-24311-05",
    "decision_type": "csv-24311-07",
    "citizenship": "csv-24311-47",
}

for year, path in SOURCE_FILES.items():
    if not path.exists():
        raise FileNotFoundError(f"Missing source file for {year}: {path}")

# %%
def load_sheet_for_all_years(sheet_name: str) -> pd.DataFrame:
    frames = []
    for year, path in SOURCE_FILES.items():
        frame = pd.read_excel(path, sheet_name=sheet_name)
        frame["source_year"] = year
        frame["source_file"] = path.name
        frames.append(frame)
    return pd.concat(frames, ignore_index=True)


df_by_article = load_sheet_for_all_years(SHEETS["by_article"])
df_decision_type = load_sheet_for_all_years(SHEETS["decision_type"])
df_citizenship = load_sheet_for_all_years(SHEETS["citizenship"])

datasets = {
    "by_article": df_by_article,
    "decision_type": df_decision_type,
    "citizenship": df_citizenship,
}

# %%
for name, frame in datasets.items():
    print(f"{name}: {frame.shape}")

df_by_article.head()
# Out:
# by_article: (124920, 12)
# decision_type: (118674, 11)
# citizenship: (18738, 10)
#                    Statistik                 Gebiet  Jahr Straftat_Gesetz  \
# 0  Strafverfolgungsstatistik  Deutschland insgesamt  2022        StGBoV
# 1  Strafverfolgungsstatistik  Deutschland insgesamt  2022        StGBoV
# 2  Strafverfolgungsstatistik  Deutschland insgesamt  2022        StGBoV
# 3  Strafverfolgungsstatistik  Deutschland insgesamt  2022        StGBoV
# 4  Strafverfolgungsstatistik  Deutschland insgesamt  2022        StGBoV
#
#                                     Art_der_Straftat  \
# 0  Straftaten ohne Straftaten im Straßenverkehr n...
# 1  Straftaten ohne Straftaten im Straßenverkehr n...
# 2  Straftaten ohne Straftaten im Straßenverkehr n...
# 3  Straftaten ohne Straftaten im Straßenverkehr n...
# 4  Straftaten ohne Straftaten im Straßenverkehr n...
#
#                 Personengruppe       Angewandtes_Strafrecht Geschlecht  \
# 0       Abgeurteilte insgesamt                            .     Männer
# 1      Abgeurteilte Erwachsene  nach allgemeinem Strafrecht     Männer
# 2  Abgeurteilte Heranwachsende  nach allgemeinem Strafrecht     Männer
# 3  Abgeurteilte Heranwachsende        nach Jugendstrafrecht     Männer
# 4     Abgeurteilte Jugendliche        nach Jugendstrafrecht     Männer
#
#   Altersgruppe Wert_Anzahl  source_year     source_file
# 0            .      376726         2022  bund-2022.xlsx
# 1            .      323834         2022  bund-2022.xlsx
# 2            .        9772         2022  bund-2022.xlsx
# 3            .       18260         2022  bund-2022.xlsx
# 4            .       24860         2022  bund-2022.xlsx
